# %%
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from sklearn import linear_model
# output to static HTML file
import numpy as np
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2d1b1af2-e9e4-4350-a102-5c4d8b5c1b7c">Loading BokehJS ...</span>
#     </div>

# %%
sales = pd.read_csv('Philadelphia_Crime_Rate_noNA.csv')

# %%
sales.head()
# Out:
#    HousePrice  HsPrc ($10,000)  CrimeRate  MilesPhila  PopChg        Name  \
# 0      140463          14.0463       29.7        10.0    -1.0    Abington
# 1      113033          11.3033       24.1        18.0     4.0      Ambler
# 2      124186          12.4186       19.5        25.0     8.0       Aston
# 3      110490          11.0490       49.4        25.0     2.7    Bensalem
# 4       79124           7.9124       54.1        19.0     3.9  Bristol B.
#
#      County
# 0  Montgome
# 1  Montgome
# 2  Delaware
# 3     Bucks
# 4     Bucks

# %%
p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle(x= sales.CrimeRate, y= sales.HousePrice, size=5, color="navy", alpha=0.5)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7567e299-70ca-446f-9de2-7f9dd513eb8b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7567e299-70ca-446f-9de2-7f9dd513eb8b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7567e299-70ca-446f-9de2-7f9dd513eb8b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7567e299-70ca-446f-9de2-7f9dd513eb8b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bb746bda-9475-4698-8ef3-c07b645f3f67":{"roots":{"references":[{"attributes":{},"id":"59174bc9-05d9-4f7c-911a-ea8f94f577d8","type":"ToolEvents"},{"attributes":{},"id":"902bf50a-5a9e-426c-9ac0-1875b24ff960","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"40d53ac9-0dd1-4262-a680-5e4b13fde546","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2e42c7f7-ef39-40ff-b6c7-884b1e913426","type":"PanTool"},{"id":"924fd028-84f9-4efb-b195-8f0e71dca918","type":"WheelZoomTool"},{"id":"f8999438-f98f-4b0b-b672-f91861977c24","type":"BoxZoomTool"},{"id":"610d3d9e-b375-4fc2-b52f-40c2f327e2eb","type":"SaveTool"},{"id":"ac9f7205-32c5-4b41-8989-d87c917372db","type":"ResetTool"},{"id":"8bc3e1cc-8382-4881-9d45-6ef054d2cb82","type":"HelpTool"}]},"id":"10d16886-cbff-4e05-988e-916e4a30781f","type":"Toolbar"},{"attributes":{"plot":null,"text":""},"id":"4fbb08a9-74c4-4668-89a7-3d9bf58abf4f","type":"Title"},{"attributes":{"callback":null},"id":"1af19133-9a29-48f5-960e-059af7fec3b8","type":"DataRange1d"},{"attributes":{},"id":"ba680c67-929b-491e-b92c-35dc65f2bb70","type":"LinearScale"},{"attributes":{},"id":"8cdfcc5e-3306-4c5d-b02a-70a88c886f75","type":"LinearScale"},{"attributes":{},"id":"55bae2ad-6b9a-46d4-a6d2-f72a20bfc031","type":"BasicTicker"},{"attributes":{"formatter":{"id":"9e086fab-003d-40d4-a458-8e73a38ff80a","type":"BasicTickFormatter"},"plot":{"id":"d5532119-90d8-465e-ac96-b04700e310cb","subtype":"Figure","type":"Plot"},"ticker":{"id":"55bae2ad-6b9a-46d4-a6d2-f72a20bfc031","type":"BasicTicker"}},"id":"cde7ff93-467b-415b-914f-bb9fff79e27e","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"navy"},"line_alpha":{"value":0.5},"line_color":{"value":"navy"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"05244a46-a5f4-4ac2-9e10-7a3ec981008d","type":"Circle"},{"attributes":{"plot":{"id":"d5532119-90d8-465e-ac96-b04700e310cb","subtype":"Figure","type":"Plot"},"ticker":{"id":"55bae2ad-6b9a-46d4-a6d2-f72a20bfc031","type":"BasicTicker"}},"id":"51f408ef-367a-48f2-bf5a-e07a1ded05e5","type":"Grid"},{"attributes":{"formatter":{"id":"902bf50a-5a9e-426c-9ac0-1875b24ff960","type":"BasicTickFormatter"},"plot":{"id":"d5532119-90d8-465e-ac96-b04700e310cb","subtype":"Figure","type":"Plot"},"ticker":{"id":"c7988c93-8e05-4298-ae7c-58abc6650dee","type":"BasicTicker"}},"id":"3f4760e7-a704-47a0-8baf-5e1c5ae15568","type":"LinearAxis"},{"attributes":{},"id":"c7988c93-8e05-4298-ae7c-58abc6650dee","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"d5532119-90d8-465e-ac96-b04700e310cb","subtype":"Figure","type":"Plot"},"ticker":{"id":"c7988c93-8e05-4298-ae7c-58abc6650dee","type":"BasicTicker"}},"id":"605c51e6-abc9-4342-8408-3d4c9b61ed69","type":"Grid"},{"attributes":{"below":[{"id":"cde7ff93-467b-415b-914f-bb9fff79e27e","type":"LinearAxis"}],"left":[{"id":"3f4760e7-a704-47a0-8baf-5e1c5ae15568","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"cde7ff93-467b-415b-914f-bb9fff79e27e","type":"LinearAxis"},{"id":"51f408ef-367a-48f2-bf5a-e07a1ded05e5","type":"Grid"},{"id":"3f4760e7-a704-47a0-8baf-5e1c5ae15568","type":"LinearAxis"},{"id":"605c51e6-abc9-4342-8408-3d4c9b61ed69","type":"Grid"},{"id":"1b31fa09-a827-4d10-a610-b6a2fd862c76","type":"BoxAnnotation"},{"id":"81aacd6e-3a53-4178-b9c1-507dae09a8ac","type":"GlyphRenderer"}],"title":{"id":"4fbb08a9-74c4-4668-89a7-3d9bf58abf4f","type":"Title"},"tool_events":{"id":"59174bc9-05d9-4f7c-911a-ea8f94f577d8","type":"ToolEvents"},"toolbar":{"id":"10d16886-cbff-4e05-988e-916e4a30781f","type":"Toolbar"},"x_range":{"id":"40d53ac9-0dd1-4262-a680-5e4b13fde546","type":"DataRange1d"},"x_scale":{"id":"ba680c67-929b-491e-b92c-35dc65f2bb70","type":"LinearScale"},"y_range":{"id":"1af19133-9a29-48f5-960e-059af7fec3b8","type":"DataRange1d"},"y_scale":{"id":"8cdfcc5e-3306-4c5d-b02a-70a88c886f75","type":"LinearScale" ...

# %%
crime_model = linear_model.LinearRegression(copy_X=False,n_jobs=-1)
# Train the model using the training sets
crime_model.fit(np.array(sales.CrimeRate).reshape(-1, 1), np.array(sales.HousePrice).reshape(-1, 1))

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle(x= sales.CrimeRate, y= sales.HousePrice, size=5, color="navy", alpha=0.5)
p.line(x= sales.CrimeRate,y= pd.DataFrame(crime_model.predict(np.array(sales.CrimeRate).reshape(-1,1)))[0] ,color ='green' )
# show the results
show(p)

print('---- Coefficient -----')
pd.DataFrame({'name': pd.Series(['(intercept)','CrimeRate']),
              'value':  pd.Series([float(crime_model.intercept_) ,float(crime_model.coef_)])})
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="13d6bc26-d1a4-4562-ba19-2b9c7b8f7ea3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("13d6bc26-d1a4-4562-ba19-2b9c7b8f7ea3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("13d6bc26-d1a4-4562-ba19-2b9c7b8f7ea3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '13d6bc26-d1a4-4562-ba19-2b9c7b8f7ea3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aa0a4ace-6264-47c6-8853-75fb8aa248b1":{"roots":{"references":[{"attributes":{"plot":{"id":"102b42c3-258c-4d21-85ce-804ff8845853","subtype":"Figure","type":"Plot"}},"id":"573c404a-277a-4770-bc73-eee425ae80b8","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8268cb2e-ad6c-4db4-8957-5cf3f6aaa54b","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"102b42c3-258c-4d21-85ce-804ff8845853","subtype":"Figure","type":"Plot"}},"id":"45c0110a-5b72-4374-b196-f33255a94d72","type":"HelpTool"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"695dcafc-30a9-491a-b8e2-7b3de0f8a079","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1f82c7d8-7c0c-45e6-b23b-0cabced06f5f","type":"Line"},{"attributes":{"data_source":{"id":"d6742b02-93f0-48c9-8968-c0f77f877e1c","type":"ColumnDataSource"},"glyph":{"id":"695dcafc-30a9-491a-b8e2-7b3de0f8a079","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1f82c7d8-7c0c-45e6-b23b-0cabced06f5f","type":"Line"},"selection_glyph":null},"id":"e9c2ca36-2b6f-4fe3-a3cf-ceec99a8c8b7","type":"GlyphRenderer"},{"attributes":{},"id":"19b0d8a6-35f7-426e-b3d3-149ad1ee7f02","type":"ToolEvents"},{"attributes":{"callback":null},"id":"396d6a27-b4ea-4486-8dac-147124cc642d","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[99]},"y":{"__ndarray__":"...","dtype":"float64","shape":[99]}}},"id":"d6742b02-93f0-48c9-8968-c0f77f877e1c","type":"ColumnDataSource"},{"attributes":{},"id":"e53f9723-200e-47cd-a5b3-c6c899f64666","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[99]},"y":[140463,113033,124186,110490,79124,92634,89246,195145,297342,264298,134342,147600,77370,170822,40642,71359,104923,190317,215512,178105,131025,149844,170556,280969,114233,74502,475112,97167,114572,436348,389302,122392,130436,272790,194435,299621,210884,112471,93738,121024,156035,185404,126160,143072,96769,94014,118214,157446,150283,153842,197214,206127,71981,169401,99843,60000,28000,60000,61800,38000,38000,42000,96200,103087,147720,78175,92215,271804,119566,100231,95831,229711,74308,259506,159573,147176,205732,215783,116710,359112,189959,133198,242821,142811,200498,199065,93648,163001,436348,124478,168276,114157,130088,152624,174232,196515,232714,245920,130953]}},"id":"0ac55596-f3cc-4f90-920c-f2b8b856050e","type":"ColumnDataSource"},{"attributes":{},"id":"98763dc1-2b08-4706-b41e-103fba0fc00f","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"navy"},"line_alpha":{"value":0.5},"line_color":{"value":"navy"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"5390f775-12af-4b03-96e7-eb3400f50860","type":"Circle"},{"attributes":{"formatter":{"id":"03689ed2-5596-4fd9-9aaa-3b3e9e7ac83a","type":"BasicTickFormatter"},"plot":{"id":"102b42c3-258c-4d21-85ce-804ff8845853","subtype":"Figure","type":"Plot"},"ticker":{"id":"98763dc1-2b08-4706-b41e-103fba0fc00f","type":"BasicTicker"}},"id":"d2a2b7a1-cb0e-4fd7-baaa-8aaa0660c038","type":"LinearAxis"},{"attributes":{"below":[{"id":"9177cd78-ea65-4368-8f08-239ca25efa3f","type":"LinearAxis"}],"left":[{"id":"d2a2b7a1-cb0e-4fd7-baaa-8aaa0660c038","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"9177cd78-ea65-4368-8f08-239ca25efa3f","type":"LinearAxis"},{"id":"8c489fe5-c6eb-424c-b345-00eab0d352a4","type":"Grid"},{"id":"d2a2b7a1-cb0e-4fd7-baaa-8aaa0660c038","type":"LinearAxis"},{"id":"5bea6d96-2c1d-48fb-9b98-46db7 ...
# ---- Coefficient -----
#           name          value
# 0  (intercept)  176629.408107
# 1    CrimeRate    -576.908128

# %%
sales_noCC = sales[sales['MilesPhila'] != 0.0]

# %%
crime_model = linear_model.LinearRegression(copy_X=False,n_jobs=-1)
# Train the model using the training sets
crime_model.fit(np.array(sales_noCC.CrimeRate).reshape(-1, 1), np.array(sales_noCC.HousePrice).reshape(-1, 1))

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle(x= sales_noCC.CrimeRate, y= sales_noCC.HousePrice, size=5, color="navy", alpha=0.5)
p.line(x= sales_noCC.CrimeRate,y= pd.DataFrame(crime_model.predict(np.array(sales_noCC.CrimeRate).reshape(-1,1)))[0] ,color ='green' )
# show the results
show(p)

print('---- Coefficient -----')
pd.DataFrame({'name': pd.Series(['(intercept)','CrimeRate']),
              'value':  pd.Series([float(crime_model.intercept_) ,float(crime_model.coef_)])})
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d5fff625-4a35-4e80-81b3-a57cd29c93bb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d5fff625-4a35-4e80-81b3-a57cd29c93bb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d5fff625-4a35-4e80-81b3-a57cd29c93bb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd5fff625-4a35-4e80-81b3-a57cd29c93bb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"77643f22-9149-4634-809b-e453e300a78d":{"roots":{"references":[{"attributes":{},"id":"4d1966b5-9a96-4033-b661-e14b67ad5d0d","type":"BasicTicker"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6a01e01a-8472-473f-a5ec-2123594d56a3","type":"Line"},{"attributes":{"plot":{"id":"3831e484-639b-4bba-96e2-988661fe97e0","subtype":"Figure","type":"Plot"}},"id":"56efaf01-9e5b-4aa6-8cfd-3be891625bd1","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[98]},"y":{"__ndarray__":"...","dtype":"float64","shape":[98]}}},"id":"148508cd-d732-4936-a2cf-23d7888f8eab","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"153b556d-3f68-482c-a411-037936d57c76","type":"BasicTickFormatter"},"plot":{"id":"3831e484-639b-4bba-96e2-988661fe97e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"cbe3f75a-36d9-4441-a729-31e9a9c1f606","type":"BasicTicker"}},"id":"3072baee-868a-44b3-8276-6a3ab9fac561","type":"LinearAxis"},{"attributes":{},"id":"3e58221c-0a5c-4063-a5b8-f1d38ac6eef0","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"3831e484-639b-4bba-96e2-988661fe97e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"cbe3f75a-36d9-4441-a729-31e9a9c1f606","type":"BasicTicker"}},"id":"b9988521-614e-40c0-909d-c77e432af3a9","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"3831e484-639b-4bba-96e2-988661fe97e0","subtype":"Figure","type":"Plot"},"ticker":{"id":"4d1966b5-9a96-4033-b661-e14b67ad5d0d","type":"BasicTicker"}},"id":"f33b1d22-1617-4cbb-a35a-9e9f22d02c6a","type":"Grid"},{"attributes":{"plot":{"id":"3831e484-639b-4bba-96e2-988661fe97e0","subtype":"Figure","type":"Plot"}},"id":"9a84bf1c-ca6a-4597-990f-3f41c02cb1f1","type":"PanTool"},{"attributes":{},"id":"cbe3f75a-36d9-4441-a729-31e9a9c1f606","type":"BasicTicker"},{"attributes":{"callback":null},"id":"caae0a60-58b8-4c2d-a7da-920c3afbb8a1","type":"DataRange1d"},{"attributes":{"data_source":{"id":"148508cd-d732-4936-a2cf-23d7888f8eab","type":"ColumnDataSource"},"glyph":{"id":"6a01e01a-8472-473f-a5ec-2123594d56a3","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2986b1fb-486f-4000-92a6-373bc7b028fd","type":"Line"},"selection_glyph":null},"id":"db28e6eb-b19d-4dd7-8601-c535b37ef207","type":"GlyphRenderer"},{"attributes":{},"id":"153b556d-3f68-482c-a411-037936d57c76","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"3072baee-868a-44b3-8276-6a3ab9fac561","type":"LinearAxis"}],"left":[{"id":"660d21c7-c644-463d-93b9-a5fe07645ae6","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"3072baee-868a-44b3-8276-6a3ab9fac561","type":"LinearAxis"},{"id":"b9988521-614e-40c0-909d-c77e432af3a9","type":"Grid"},{"id":"660d21c7-c644-463d-93b9-a5fe07645ae6","type":"LinearAxis"},{"id":"f33b1d22-1617-4cbb-a35a-9e9f22d02c6a","type":"Grid"},{"id":"847844f4-ac24-49ea-b2f2-d6d909718fa0","type":"BoxAnnotation"},{"id":"85a45ac8-710c-45e8-91c6-e4a83061961a","type":"GlyphRenderer"},{"id":"db28e6eb-b19d-4dd7-8601-c535b37ef207","type":"GlyphRenderer"}],"title":{"id":"c0c4d707-b932-468c-a7f5-c53dde4a2555","type":"Title"},"tool_events":{"id":"331cfda3-3304-4b2e-a822-89099f214e43","type":"ToolEvents"},"toolbar":{"id":"45546053-1a4e-49db-bb81-6a92f5b8bca7","type":"Toolbar"},"x_range":{"id":"cc81aa78-e5ce-47bb-bc16-fb5d9bc97e96","type":"DataRange1d"},"x_scale":{"id":"511c9bd4-5eaa-4d4c-861b-0b54e7ba23f1","type":"LinearScale"},"y_range":{"id":"caae0a60-58b8-4c2d-a7da-920c3afbb8a1","type":"DataRange1d"},"y_scale":{"id":"c5c259e4-0ea8-46d2-9d8a-b49bed4ea456","type":"LinearScale"}},"id":"3831e484-639b-4bba-96e2-988661fe97e0","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"331cfda3-3304-4b2e-a822-89099f214e43","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[98]},"y":[140463,113033,124186,110490,79124,92634,89246,195145, ...
# ---- Coefficient -----
#           name          value
# 0  (intercept)  225233.551839
# 1    CrimeRate   -2288.689430
