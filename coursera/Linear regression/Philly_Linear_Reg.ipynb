# %%
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from sklearn import linear_model
# output to static HTML file
import numpy as np
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9293cdd8-a123-4096-8c01-031ab3c942fd">Loading BokehJS ...</span>
#     </div>

# %%
sales = pd.read_csv('Philadelphia_Crime_Rate_noNA.csv')

# %%
sales.head()
# Out:
#    HousePrice  HsPrc ($10,000)  CrimeRate  MilesPhila  PopChg        Name  \
# 0      140463          14.0463       29.7        10.0    -1.0    Abington
# 1      113033          11.3033       24.1        18.0     4.0      Ambler
# 2      124186          12.4186       19.5        25.0     8.0       Aston
# 3      110490          11.0490       49.4        25.0     2.7    Bensalem
# 4       79124           7.9124       54.1        19.0     3.9  Bristol B.
#
#      County
# 0  Montgome
# 1  Montgome
# 2  Delaware
# 3     Bucks
# 4     Bucks

# %%
p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle(x= sales.CrimeRate, y= sales.HousePrice, size=5, color="navy", alpha=0.5)

# show the results
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="76bb834d-e73b-4262-85c6-19d3772784c0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("76bb834d-e73b-4262-85c6-19d3772784c0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("76bb834d-e73b-4262-85c6-19d3772784c0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '76bb834d-e73b-4262-85c6-19d3772784c0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d68d9633-ef2d-4799-8203-9978581f9caa":{"roots":{"references":[{"attributes":{},"id":"36ed2906-bbf2-474e-a3af-0f881992ea91","type":"BasicTicker"},{"attributes":{},"id":"9d07a5d1-b881-411a-876f-e1da7baf0069","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"67517725-6d86-4b1e-81fa-b62e77148048","subtype":"Figure","type":"Plot"},"ticker":{"id":"1bba8da4-a4d4-4e36-be87-297af3031684","type":"BasicTicker"}},"id":"2116e4f5-ad64-457d-ab56-cb66985e492b","type":"Grid"},{"attributes":{"plot":{"id":"67517725-6d86-4b1e-81fa-b62e77148048","subtype":"Figure","type":"Plot"}},"id":"932b1eab-3de2-4672-b299-a6e30a1533e3","type":"SaveTool"},{"attributes":{"data_source":{"id":"15444fb1-8f43-4c3b-902b-098a31c51dde","type":"ColumnDataSource"},"glyph":{"id":"0b171220-0947-425e-8561-00edb80ecb80","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ec9cb296-4164-4866-b8bf-99d1b9b13695","type":"Circle"},"selection_glyph":null},"id":"57308afe-d6ae-4658-9060-aff0914eccd7","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"67517725-6d86-4b1e-81fa-b62e77148048","subtype":"Figure","type":"Plot"},"ticker":{"id":"36ed2906-bbf2-474e-a3af-0f881992ea91","type":"BasicTicker"}},"id":"7f780f7e-a6b0-469a-b59c-eca8216171ef","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"navy"},"line_alpha":{"value":0.5},"line_color":{"value":"navy"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"0b171220-0947-425e-8561-00edb80ecb80","type":"Circle"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f0b86252-b566-447b-9f88-3baf979c10f7","type":"PanTool"},{"id":"b39ab7dd-7bb0-4304-bea5-0362ec70600f","type":"WheelZoomTool"},{"id":"da0a7020-6142-460c-ba68-66f8675df473","type":"BoxZoomTool"},{"id":"932b1eab-3de2-4672-b299-a6e30a1533e3","type":"SaveTool"},{"id":"5fce4523-79b9-402e-838c-651d5fcdbe4b","type":"ResetTool"},{"id":"aefda5ce-59b8-4266-93eb-ed14e39ac6cd","type":"HelpTool"}]},"id":"bdc08398-fbeb-4a40-860a-a2479716dab7","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b3893afd-aeb5-43d7-aac9-6cb229570deb","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"67517725-6d86-4b1e-81fa-b62e77148048","subtype":"Figure","type":"Plot"}},"id":"f0b86252-b566-447b-9f88-3baf979c10f7","type":"PanTool"},{"attributes":{"formatter":{"id":"9d07a5d1-b881-411a-876f-e1da7baf0069","type":"BasicTickFormatter"},"plot":{"id":"67517725-6d86-4b1e-81fa-b62e77148048","subtype":"Figure","type":"Plot"},"ticker":{"id":"36ed2906-bbf2-474e-a3af-0f881992ea91","type":"BasicTicker"}},"id":"da10a004-ea4a-4af1-8c51-4a67214c569e","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[99]},"y":[140463,113033,124186,110490,79124,92634,89246,195145,297342,264298,134342,147600,77370,170822,40642,71359,104923,190317,215512,178105,131025,149844,170556,280969,114233,74502,475112,97167,114572,436348,389302,122392,130436,272790,194435,299621,210884,112471,93738,121024,156035,185404,126160,143072,96769,94014,118214,157446,150283,153842,197214,206127,71981,169401,99843,60000,28000,60000,61800,38000,38000,42000,96200,103087,147720,78175,92215,271804,119566,100231,95831,229711,74308,259506,159573,147176,205732,215783,116710,359112,189959,133198,242821,142811,200498,199065,93648,163001,436348,124478,168276,114157,130088,152624,174232,196515,232714,245920,130953]}},"id":"15444fb1-8f43-4c3b-902b-098a31c51dde","type":"ColumnDataSource"},{"attributes":{},"id":"1bba8da4-a4d4-4e36-be87-297af3031684","type":"BasicTicker"},{"attributes":{"callback":null},"id":"d7e4bc1b-3dfb-490e-b57a ...

# %%
crime_model = linear_model.LinearRegression(copy_X=False,n_jobs=-1)
# Train the model using the training sets
crime_model.fit(np.array(sales.CrimeRate).reshape(-1, 1), np.array(sales.HousePrice).reshape(-1, 1))

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle(x= sales.CrimeRate, y= sales.HousePrice, size=5, color="navy", alpha=0.5)
p.line(x= sales.CrimeRate,y= pd.DataFrame(crime_model.predict(np.array(sales.CrimeRate).reshape(-1,1)))[0] ,color ='green' )
# show the results
show(p)

print('---- Coefficient -----')
pd.DataFrame({'name': pd.Series(['(intercept)','CrimeRate']),
              'value':  pd.Series([float(crime_model.intercept_) ,float(crime_model.coef_)])})
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b18f4c00-2327-4375-80a5-e7e99f8c92e9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b18f4c00-2327-4375-80a5-e7e99f8c92e9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b18f4c00-2327-4375-80a5-e7e99f8c92e9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b18f4c00-2327-4375-80a5-e7e99f8c92e9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ea98bbc0-9525-4fac-aadc-c4e3ff5b0409":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"82cd4e19-323a-487b-ac3d-9aaf873ac840","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"0c5d03c5-6dea-4bd3-82ba-c3c038ed9ab4","type":"LinearAxis"}],"left":[{"id":"267e483f-23ab-4b15-a073-bd7158bc489a","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"0c5d03c5-6dea-4bd3-82ba-c3c038ed9ab4","type":"LinearAxis"},{"id":"156247f6-5a95-46c7-b702-80aec4ba8c95","type":"Grid"},{"id":"267e483f-23ab-4b15-a073-bd7158bc489a","type":"LinearAxis"},{"id":"e0189e87-e8a2-4db1-80bc-d695dbb43b4f","type":"Grid"},{"id":"82cd4e19-323a-487b-ac3d-9aaf873ac840","type":"BoxAnnotation"},{"id":"16c07076-1356-4b95-830e-3b000d94d42b","type":"GlyphRenderer"},{"id":"6007aac9-c8c5-46e6-a006-2776c57da535","type":"GlyphRenderer"}],"title":{"id":"59b15233-9b76-486b-9225-9501fe6c8ddd","type":"Title"},"tool_events":{"id":"97655e21-b358-41f0-802a-f9c96b5cda8d","type":"ToolEvents"},"toolbar":{"id":"e333c317-c75a-4f07-bab0-5767b12b5cd1","type":"Toolbar"},"x_range":{"id":"db958f51-581c-4972-be69-8aaaed820c4f","type":"DataRange1d"},"y_range":{"id":"dd0749ec-5564-4ca9-88a4-c3b75fca6886","type":"DataRange1d"}},"id":"b02811c1-8591-4441-891b-0d11a1118809","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"b02811c1-8591-4441-891b-0d11a1118809","subtype":"Figure","type":"Plot"}},"id":"97e981f0-8f48-429a-a126-2192273a4ae9","type":"PanTool"},{"attributes":{},"id":"1cf4159b-1758-4552-b4b5-0ea4a3b80dc7","type":"BasicTickFormatter"},{"attributes":{},"id":"97655e21-b358-41f0-802a-f9c96b5cda8d","type":"ToolEvents"},{"attributes":{"plot":{"id":"b02811c1-8591-4441-891b-0d11a1118809","subtype":"Figure","type":"Plot"}},"id":"ba54a9f5-6f74-4f30-a9be-c4d6ac109d37","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"82cd4e19-323a-487b-ac3d-9aaf873ac840","type":"BoxAnnotation"},"plot":{"id":"b02811c1-8591-4441-891b-0d11a1118809","subtype":"Figure","type":"Plot"}},"id":"c4f088ba-a4e8-4424-a47e-b8a104f7e229","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"b02811c1-8591-4441-891b-0d11a1118809","subtype":"Figure","type":"Plot"}},"id":"494d2d0e-7041-49e9-b306-c45591799403","type":"SaveTool"},{"attributes":{"plot":{"id":"b02811c1-8591-4441-891b-0d11a1118809","subtype":"Figure","type":"Plot"}},"id":"808ec95c-bcf7-44f2-9e8e-8ad404b9eea8","type":"ResetTool"},{"attributes":{"plot":{"id":"b02811c1-8591-4441-891b-0d11a1118809","subtype":"Figure","type":"Plot"}},"id":"6829ed1a-e923-497f-9dc2-2bb5b3218fc8","type":"HelpTool"},{"attributes":{},"id":"5344e313-1657-4946-afd0-bb0359824197","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"3e260ab0-4377-4c8c-b453-6dd26a6f9acd","type":"ColumnDataSource"},"glyph":{"id":"ca2fd5d4-2b14-4630-bcd8-3904313cfc2c","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"b1902c57-b829-4511-bf3b-c4a81e99060a","type":"Circle"},"selection_glyph":null},"id":"16c07076-1356-4b95-830e-3b000d94d42b","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fc956b0d-91c0-4513-9f0e-df585c1aa34f","type":"Line"},{"attributes":{"callback":null},"id":"db958f51-581c-4972-be69-8aaaed820c4f","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"97e981f0-8f48-429a-a126-2192273a4ae9","type":"PanTool"},{"id":"ba54a9f5-6f74-4f30-a9be-c4d6ac109d37","type":"WheelZoomTool"},{"id":"c4f088ba-a4e8-4424-a47e-b8a104f7e229","type":"BoxZoomTool"},{"id":"494d2d0e-7041-49e9-b306-c45591799403","type":"SaveTool"},{"id":"808ec95c-bcf7-44f2-9e8e-8ad404b9eea8","typ ...
# ---- Coefficient -----
#           name          value
# 0  (intercept)  176629.408107
# 1    CrimeRate    -576.908128

# %%
sales_noCC = sales[sales['MilesPhila'] != 0.0]

# %%
crime_model = linear_model.LinearRegression(copy_X=False,n_jobs=-1)
# Train the model using the training sets
crime_model.fit(np.array(sales_noCC.CrimeRate).reshape(-1, 1), np.array(sales_noCC.HousePrice).reshape(-1, 1))

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle(x= sales_noCC.CrimeRate, y= sales_noCC.HousePrice, size=5, color="navy", alpha=0.5)
p.line(x= sales_noCC.CrimeRate,y= pd.DataFrame(crime_model.predict(np.array(sales_noCC.CrimeRate).reshape(-1,1)))[0] ,color ='green' )
# show the results
show(p)

print('---- Coefficient -----')
pd.DataFrame({'name': pd.Series(['(intercept)','CrimeRate']),
              'value':  pd.Series([float(crime_model.intercept_) ,float(crime_model.coef_)])})
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bbb4c14f-4095-469b-acc1-9a85a0488957"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bbb4c14f-4095-469b-acc1-9a85a0488957");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bbb4c14f-4095-469b-acc1-9a85a0488957");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bbb4c14f-4095-469b-acc1-9a85a0488957' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a862e03d-feed-4481-af9c-7aca8d0a0023":{"roots":{"references":[{"attributes":{},"id":"7c0d94b2-8730-4693-acdd-58903fa6c39e","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"01b6e398-914c-4c5f-9460-50fc746547aa","subtype":"Figure","type":"Plot"},"ticker":{"id":"7c0d94b2-8730-4693-acdd-58903fa6c39e","type":"BasicTicker"}},"id":"699789e6-5d71-4361-82e8-fdc2a97e6b9f","type":"Grid"},{"attributes":{"formatter":{"id":"86ee4b58-0238-4f23-b44f-7a883d4a36e0","type":"BasicTickFormatter"},"plot":{"id":"01b6e398-914c-4c5f-9460-50fc746547aa","subtype":"Figure","type":"Plot"},"ticker":{"id":"46d03eb0-6156-4ed6-a2ab-67cd4b3adc38","type":"BasicTicker"}},"id":"300ec1b6-3693-4d5c-85c1-6ef7703c8c21","type":"LinearAxis"},{"attributes":{},"id":"46d03eb0-6156-4ed6-a2ab-67cd4b3adc38","type":"BasicTicker"},{"attributes":{"data_source":{"id":"741d09c8-36d9-454f-bea6-34e18ab56fb8","type":"ColumnDataSource"},"glyph":{"id":"8b878ee5-8325-4376-8257-5576c5bfb39a","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4aa93b69-47da-4c46-8b7d-23b24e3e89c5","type":"Circle"},"selection_glyph":null},"id":"120841d7-848a-42b0-9319-331dd32dccb0","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"ac412994-431c-4dda-8569-80651830858e","type":"BasicTickFormatter"},"plot":{"id":"01b6e398-914c-4c5f-9460-50fc746547aa","subtype":"Figure","type":"Plot"},"ticker":{"id":"7c0d94b2-8730-4693-acdd-58903fa6c39e","type":"BasicTicker"}},"id":"39bcffa7-890f-4f24-b272-66bb04cd2929","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"e5996569-d2ec-49a9-bce3-58b5d5665ef9","type":"Title"},{"attributes":{"callback":null},"id":"b870fb71-984b-4e45-bc88-6e45f686c508","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"4aa93b69-47da-4c46-8b7d-23b24e3e89c5","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"51847fca-0a57-44bc-ba9f-73684ed75af7","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"01b6e398-914c-4c5f-9460-50fc746547aa","subtype":"Figure","type":"Plot"}},"id":"d98a799b-55de-460b-a486-ba61d8550d1c","type":"PanTool"},{"attributes":{},"id":"ac412994-431c-4dda-8569-80651830858e","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"01b6e398-914c-4c5f-9460-50fc746547aa","subtype":"Figure","type":"Plot"}},"id":"638a17b7-fe64-444d-9985-f74cd63b2c06","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d98a799b-55de-460b-a486-ba61d8550d1c","type":"PanTool"},{"id":"638a17b7-fe64-444d-9985-f74cd63b2c06","type":"WheelZoomTool"},{"id":"43fa032c-36f0-404b-a6a1-46673bb2ebeb","type":"BoxZoomTool"},{"id":"437cef40-04f4-4e79-ba74-0f457da2345c","type":"SaveTool"},{"id":"0b5c6827-ee99-4c90-815e-7bd51431c506","type":"ResetTool"},{"id":"57f03d04-5460-4586-874c-4cf27ac197d3","type":"HelpTool"}]},"id":"449ca7a8-2282-4367-bed8-42a2dc96630e","type":"Toolbar"},{"attributes":{"overlay":{"id":"51847fca-0a57-44bc-ba9f-73684ed75af7","type":"BoxAnnotation"},"plot":{"id":"01b6e398-914c-4c5f-9460-50fc746547aa","subtype":"Figure","type":"Plot"}},"id":"43fa032c-36f0-404b-a6a1-46673bb2ebeb","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"01b6e398-914c-4c5f-9460-50fc746547aa","subtype":"Figure","type":"Plot"}},"id":"437cef40-04f4-4e79-ba74-0f457da2345c","type":"SaveTool"},{"attributes":{"plot":{"id":"01b6e398-914c-4c5f-9460-50fc746547aa","subtype":"Figure","type":"Plot"}},"id":"0b5c6827-ee99-4c90-815e-7bd51431c506","type":"ResetTool"},{"attributes":{"plot":{"id":"01b6e398-914c-4c5f-946 ...
# ---- Coefficient -----
#           name          value
# 0  (intercept)  225233.551839
# 1    CrimeRate   -2288.689430

# %% [markdown]
# #### Remove high end points

# %%
sales_nohighend = sales_noCC[sales_noCC['HousePrice'] < 350000] 
crime_model_nohighend = linear_model.LinearRegression(copy_X=False,n_jobs=-1)
crime_model_nohighend.fit(np.array(sales_nohighend.CrimeRate).reshape(-1, 1),
                          np.array(sales_nohighend.HousePrice).reshape(-1, 1))
print('---- Coefficient -----')
pd.DataFrame({'name': pd.Series(['(intercept)','CrimeRate']),
              'value':  pd.Series([float(crime_model_nohighend.intercept_) ,float(crime_model_nohighend.coef_)])})
# Out:
# ---- Coefficient -----
#           name          value
# 0  (intercept)  199098.852670
# 1    CrimeRate   -1838.562649
