# %%
import pandas as pd

# %%
df = pd.read_csv('dataverse_files/Bhavnani India State Election Dataset v 3.0.tab',sep='\t')

# %%
df[df.year == 2013].st_name.unique()
# Out:
# array(['Chhattisgarh', 'Karnataka', 'Madhya Pradesh', 'Meghalaya',
#        'Mizoram', 'Nagaland', 'National Capital Territory Of Delhi',
#        'Rajasthan', 'Tripura'], dtype=object)

# %%
df[(df.st_name =='Madhya Pradesh') & (df.year == 2013)]
# Out:
#                st_name    year  ac_no      ac_name ac_type  \
# 156575  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156576  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156577  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156578  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156579  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156580  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156581  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156582  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156583  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156584  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156585  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156586  Madhya Pradesh  2013.0      1     Sheopur      GEN
# 156587  Madhya Pradesh  2013.0      2    Vijaypur      GEN
# 156588  Madhya Pradesh  2013.0      2    Vijaypur      GEN
# 156589  Madhya Pradesh  2013.0      2    Vijaypur      GEN
# ...

# %%
()
