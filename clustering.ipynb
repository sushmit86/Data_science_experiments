# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(min_df=1)
import pandas as pd
print(vectorizer)
import scipy as sp
import numpy as np
from numpy.random import randint
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# All bokeh library
from bokeh.io import output_notebook
import bokeh
from bokeh.plotting import figure, show
from bokeh.charts import Histogram
from bokeh.palettes import Viridis256
print(bokeh.__version__)
TOOLS="hover"
output_notebook()
# Out:
# 0.12.4
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="12ac0a3b-1e7d-42cd-b98d-2965718b0bfd">Loading BokehJS ...</span>
#     </div>

# %%
df1 = pd.read_csv('Machine_learning/ch01/data/web_traffic.tsv',sep= '\t',header=None)
df1.head()
x = df1[0]
y = df1[1]

# %%
print(df1.shape)
sum(pd.isnull(y))
# Out:
# (743, 2)
# 8

# %%
df1.dropna(axis =0, inplace=True)
df1.head()
x = df1[0]
y = df1[1]

# %%
p = figure(tools=TOOLS)
p.scatter(x,y)
p.xaxis.axis_label = 'Weeks'
p.yaxis.axis_label = 'Hits/hour'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0e702eaf-ce12-42be-a99b-58b3ee36e8b6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
fp1, residuals, rank, sv,rcond = sp.polyfit(x,y,1,full = True)

# %%
print("Model parameters: %s" % fp1)
print(residuals)
# Out:
# Model parameters: [   2.59619213  989.02487106]
# [  3.17389767e+08]

# %%
def error(f,x,y):
    return sp.sum((f(x) - y)**2)

# %%
f1 = sp.poly1d(fp1)
print(sp.poly1d(f1))
print(error(f1,x,y))
# Out:
#
# 2.596 x + 989
# 317389767.3397781

# %%
fx = sp.linspace(0,x.ix[742],1000) # generate X values
p = figure(tools=TOOLS)
p.scatter(x,y)
p.line(fx, f1(fx), line_width =3, color ='green')
p.xaxis.axis_label = 'Weeks'
p.yaxis.axis_label = 'Hits/hour'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7c41f129-a0a3-4598-881c-abbbd3a367f5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
f2p = sp.polyfit(x,y,2)
print(f2p)
f2 = sp.poly1d(f2p)
print(error(f2,x,y))
# Out:
# [  1.05322215e-02  -5.26545650e+00   1.97476082e+03]
# 179983507.8781793

# %%
fx = sp.linspace(0,x.ix[742],1000) # generate X values
p = figure(tools=TOOLS)
p.scatter(x,y)
p.scatter(fx, f1(fx), color = colors[0],legend = 'd = 1' )
p.line(fx, f2(fx), color ='black')
p.xaxis.axis_label = 'Weeks'
p.yaxis.axis_label = 'Hits/hour'
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9c70e025-1696-4101-9a0a-597568370296"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
p = figure(tools=TOOLS)
p.scatter(x,y, color = Viridis256[randint(0,256)],legend = 'Data')
fx = sp.linspace(0,x.ix[742],1000) # generate X values
d = [1,2,3,10,100]
for i in d:
    fdp = sp.polyfit(x,y,i)
    fd = sp.poly1d(fdp)
    print("Error d = %d: %f"%(i,error(fd,x,y)))
    legend = ("d = %d" %(i))
    p.line(fx, fd(fx), color = Viridis256[randint(0,256)],line_width=2,legend = legend)

p.xaxis.axis_label = 'Weeks'
p.yaxis.axis_label = 'Hits/hour'
show(p)
# Out:
# Error d = 1: 317389767.339778
# Error d = 2: 179983507.878179
# Error d = 3: 139350144.031725
# Error d = 10: 121942326.363547
# Error d = 100: 109452399.050827
# /Users/sroy/anaconda/lib/python3.5/site-packages/numpy/lib/polynomial.py:587: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /Users/sroy/anaconda/lib/python3.5/site-packages/numpy/lib/polynomial.py:595: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ff42e896-e88f-413d-beef-088061330803"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
# ...

# %%
np.random.randint(0,256)
# Out:
# 148
