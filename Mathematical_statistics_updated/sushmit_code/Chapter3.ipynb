# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
plt.style.use('fivethirtyeight')

# %%
df_beer_data = pd.read_csv('Data/Beerwings.csv')
df_beer_data.head()

df_beer_data.groupby(by= ['Gender']).agg(mean_wings = ('Hotwings',np.mean),
                                         std_dev_wings = ('Hotwings',np.std),
                                        count_gender = ('Gender','count')).reset_index()
# Out:
#   Gender  mean_wings  std_dev_wings  count_gender
# 0      F    9.333333       3.559026            15
# 1      M   14.533333       4.501851            15

# %%
df_beer_data.head()
# Out:
#    ID  Hotwings  Beer Gender
# 0   1         4    24      F
# 1   2         5     0      F
# 2   3         5    12      F
# 3   4         6    12      F
# 4   5         7    12      F

# %%
observed_value = 14.533333 - 9.333333

# %%
fig,axs = plt.subplots(1,1,figsize = (12,8))
sns.boxplot(x='Gender',y = 'Hotwings',data = df_beer_data, ax = axs)
plt.show()

# %%
N = 99998
t_stat = []
for _i in range(N):
    _df_female,_df_male = train_test_split(df_beer_data,train_size=0.5)
    t_stat.append(_df_female.Hotwings.mean() - _df_male.Hotwings.mean())

# %%
fig,axs = plt.subplots(1,1, figsize = (10,8))
sns.histplot(t_stat,ax=axs)
plt.show()

# %%
np.sum(np.array(t_stat) > observed_value)/10**5
# Out:
# 0.00073
