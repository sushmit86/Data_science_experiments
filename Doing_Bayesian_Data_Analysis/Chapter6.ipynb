# %%
import user_defined_functions as udf
from scipy.stats import beta
import numpy as np
from IPython.display import display
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# Specify the prior:
t = 0.75             # Specify the prior MODE.
n = 25               # Specify the effective prior sample size.
a = t*(n-2) + 1      # Convert to beta shape parameter a.
b = (1-t)*(n-2) + 1  # Convert to beta shape parameter b.
# Specify the data:
N = 20                         # The total number of flips.
z = 17                         # The number of heads.
Data = np.concatenate((np.ones(z),np.zeros(N-z)))

# %%
udf.BernBeta((a,b),Data)
# Out:
# (35.25, 9.75)

# %% [markdown]
# ### Exercise 6.1

# %%
## Start with prior of beta(θ/4,4)
display('#'*50 +'6(a)'+ '#'*50  )
a = 4
b = 4
N = 1                         # The total number of flips.
z = 1                         # The number of heads.
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
(a,b) = udf.BernBeta((a,b),Data)
## Start with prior of prev posterior
display('#'*50 +'6(b)'+ '#'*50  )
N = 1                         # The total number of flips.
z = 1                         # The number of heads.
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
(a,b) = udf.BernBeta((a,b),Data)
## Start with prior of prev posterior
display('#'*50 +'6(c)'+ '#'*50  )
N = 1                         # The total number of flips.
z = 0                         # The number of heads.
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
(a,b) = udf.BernBeta((a,b),Data)


## Start with prior of beta(θ/4,4)
display('#'*50 +'6(d)'+ '#'*50  )
a = 4
b = 4
N = 1                         # The total number of flips.
z = 0                         # The number of heads.
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
(a,b) = udf.BernBeta((a,b),Data)
## Start with prior of prev posterior
N = 1                         # The total number of flips.
z = 1                         # The number of heads.
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
(a,b) = udf.BernBeta((a,b),Data)
## Start with prior of prev posterior
N = 1                         # The total number of flips.
z = 1                         # The number of heads.
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
(a,b) = udf.BernBeta((a,b),Data)
# Out:
# '##################################################6(a)##################################################'
# '##################################################6(b)##################################################'
# '##################################################6(c)##################################################'
# '##################################################6(d)##################################################'

# %% [markdown]
# ### Ex6.2

# %%
## Start with prior of beta(θ/1,1)
display('#'*50 +'6.2(a)'+ '#'*50  )
a = 1
b = 1
N = 100                         # Number of people sampled
z = 58                         # Number of people prefer A
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
(a,b) = udf.BernBeta((a,b),Data)
display('#'*50 +'6.2(b)'+ '#'*50  )
## Start with prior of prev posterior
N = 100                         # Number of people sampled
z = 57                         # Number of people prefer A
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
udf.BernBeta((a,b),Data)
# Out:
# '##################################################6.2(a)##################################################'
# '##################################################6.2(b)##################################################'
# (116.0, 86.0)

# %% [markdown]
# ## Exercise 6.3

# %%
## Start with prior of beta(θ/1,1)
display('#'*50 +'6.3'+ '#'*50  )
a = 1
b = 1
N = 50                         # Number of people sampled
z = 40                         # Number of people press F on radio
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
udf.BernBeta((a,b),Data)


## Start with prior of beta(θ/1,1)
display('#'*50 +'6.3 for ocean + mtn'+ '#'*50  )
a = 1
b = 1
N = 50                         # Number of people sampled
z = 15                         # Number of people press F on radio
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
udf.BernBeta((a,b),Data)
# Out:
# '##################################################6.3##################################################'
# '##################################################6.3 for ocean + mtn##################################################'
# (16.0, 36.0)

# %% [markdown]
# ### Exercise 6.4

# %%
## Start with prior of beta(θ/1,1)
display('#'*50 +'6.4'+ '#'*50  )
a = 0.1
b = 0.1
N = 5                        # Number of Trials
z = 4                        # Number of Heads
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
udf.BernBeta((a,b),Data)
# Out:
# '##################################################6.4##################################################'
# (4.1, 1.0999999999999996)

# %% [markdown]
# ## Exercise 6.5

# %%
## Start with prior of beta(θ/1,1)
display('#'*50 +'6.5 (a)'+ '#'*50  )
# we use uniform prior as our prior
a = 500
b = 500
N = 10                        # Number of Trials
z = 9                        # Number of Heads
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
udf.BernBeta((a,b),Data)

## Start with prior of beta(θ/1,1)
display('#'*50 +'6.5 (b)'+ '#'*50  )
# we use extreme priors
a = 0.1
b = 0.1
N = 10                        # Number of Trials
z = 9                        # Number of Heads
Data = np.concatenate((np.ones(z),np.zeros(N-z)))
udf.BernBeta((a,b),Data)
# Out:
# '##################################################6.5 (a)##################################################'
# '##################################################6.5 (b)##################################################'
# (9.1, 1.0999999999999996)
