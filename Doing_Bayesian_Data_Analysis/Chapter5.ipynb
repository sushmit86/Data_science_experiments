# %% [markdown]
# ### Exercise 5.5 Berngrid examples

# %%
import pandas as pd
import numpy as np
from scipy import stats
import xarray
from user_defined_functions import BernGrid
np.random.seed(1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Exercise 5.4

# %%
## Example 0
Theta = np.linspace(0,1,5,dtype=np.float32) # Sparse teeth for Theta.
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum() # Make pTheta sum to 1.0
Data = np.ones(1,dtype = np.int16) # Single flip with 1 head
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="62058d27-e930-497b-96f3-0df137bfcc2e"></div>

# %%
## Example1
Theta = np.linspace(0,1,11,dtype=np.float32) # Sparse teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum() # Make pTheta sum to 1.0
Data = np.ones(1,dtype= np.int16) # Single flip with 1 head
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="eb841ea4-8286-492d-8465-d27409474bd6"></div>

# %%
## Eaxmple 2
Theta = np.linspace(0,1,1001,dtype=np.float32) # fine teeth for Theta. 
pTheta = np.ones(len(Theta),dtype = np.float32) ## 
pTheta = pTheta/pTheta.sum() # Make pTheta sum to 1.0
Data = np.ones(1,dtype= np.int16) # Single flip with 1 head
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="55aa0a69-2c85-47b1-898d-e46cc7045cef"></div>

# %%
## Example 3
Theta = np.linspace(0,1,1001,dtype=np.float32) # fine teeth for Theta. 
pTheta = np.zeros(len(Theta),dtype = np.float32)
pTheta[1] =1 ## 
pTheta[-2] = 1
pTheta = pTheta/pTheta.sum()
Data = np.ones(1,dtype= np.int16) # Single flip with 1 head
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="a6049f67-a994-498c-ad53-d847f3a2a4ba"></div>

# %%
## Example 4
Theta = np.linspace(0,1,1001,dtype=np.float32) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(3, dtype = np.int16),np.ones(1,dtype = np.int16)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="1f8a60d5-d952-4dca-8188-7354bee2f4c4"></div>

# %%
## Example 5
Theta = np.linspace(0,1,1001,dtype=np.float32) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
pTheta = pTheta**10
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(3, dtype = np.int16),np.ones(1,dtype = np.int16)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="c0ba571a-769e-49dd-8a3f-74b5161289ee"></div>

# %%
## Example 6
Theta = np.linspace(0,1,1001,dtype=np.float32) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
pTheta = pTheta**0.1
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(3, dtype = np.int16),np.ones(1,dtype = np.int16)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="41d20f32-9812-46da-99d5-d7c1322fb336"></div>

# %%
## Example7
Theta = np.linspace(0,1,1001,dtype=np.float32) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(30, dtype = np.int16),np.ones(10,dtype = np.int16)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="2887d960-210e-4545-8044-cc5712130ab7"></div>

# %%
## Example 8
Theta = np.linspace(0,1,1001,dtype=np.float32) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
pTheta = pTheta**10
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(30, dtype = np.int16),np.ones(10,dtype = np.int16)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="2ac6bf31-4f04-41df-bb52-6872826e1f1a"></div>

# %%
## Example 9
Theta = np.linspace(0,1,1001,dtype=np.float32) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
pTheta = pTheta**0.1
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(30, dtype = np.int16),np.ones(10,dtype = np.int16)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="a47aa30b-f079-4f3f-8ace-30a483d32e62"></div>
