# %% [markdown]
# ### Exercise 5.5 Berngrid examples

# %%
import pandas as pd
import numpy as np
from scipy import stats
import xarray
from user_defined_functions import BernGrid
np.random.seed(1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Exercise 5.4

# %%
## Example 0
Theta = np.linspace(0,1,5) # Sparse teeth for Theta.
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum() # Make pTheta sum to 1.0
Data = np.ones(1) # Single flip with 1 head
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="35100ca8-17aa-4f6f-b688-5eb841671344"></div>

# %%
## Example1
Theta = np.linspace(0,1,11) # Sparse teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum() # Make pTheta sum to 1.0
Data = np.ones(1) # Single flip with 1 head
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="e7c59dc1-6cb7-4333-b1fa-805ebd536252"></div>

# %%
## Eaxmple 2
Theta = np.linspace(0,1,1001) # fine teeth for Theta. 
pTheta = np.ones(len(Theta)) ## 
pTheta = pTheta/pTheta.sum() # Make pTheta sum to 1.0
Data = np.ones(1) # Single flip with 1 head
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="ce574618-c458-4edc-b5f3-c24295381431"></div>

# %%
## Example 3
Theta = np.linspace(0,1,1001) # fine teeth for Theta. 
pTheta = np.zeros(len(Theta))
pTheta[1] =1 ## 
pTheta[-2] = 1
pTheta = pTheta/pTheta.sum()
Data = np.ones(1) # Single flip with 1 head
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="782012fd-3cbf-4c3e-8161-263f70df3eb9"></div>

# %%
## Example 4
Theta = np.linspace(0,1,1001) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(3),np.ones(1)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="017bf099-4672-49a4-95a9-19ee1838aae0"></div>

# %%
## Example 5
Theta = np.linspace(0,1,1001) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
pTheta = pTheta**10
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(3),np.ones(1)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="a697d6a1-3c7b-4c8a-b8fa-edfd3160188a"></div>

# %%
## Example 6
Theta = np.linspace(0,1,1001) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
pTheta = pTheta**0.1
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(3),np.ones(1)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="29d2800d-7acd-4ae8-bb61-fcaab06f4830"></div>

# %%
## Example7
Theta = np.linspace(0,1,1001) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(30),np.ones(10)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="5e30cdba-cd8c-4e81-9d74-34996ce7aed4"></div>

# %%
## Example 8
Theta = np.linspace(0,1,1001) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
pTheta = pTheta**10
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(30),np.ones(10)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="f39e8a7d-faf7-4030-88b4-750fbcf1a754"></div>

# %%
## Example 9
Theta = np.linspace(0,1,1001) # fine teeth for Theta. 
pTheta = np.minimum(Theta,1 - Theta) # Triangular shape for pTheta.
pTheta = pTheta/pTheta.sum()
pTheta = pTheta**0.1
pTheta = pTheta/pTheta.sum()
Data = np.concatenate((np.zeros(30),np.ones(10)))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="1eefb3a1-814d-4030-9dff-1306ba0d4105"></div>

# %%
## Example 10
Theta = np.linspace(0,1,1000) # fine teeth for Theta. 
pTheta = np.concatenate((np.ones(200),np.linspace(1,100,50)
                        ,np.linspace(100,1,50),
                        np.ones(200)))
pTheta = np.tile(pTheta,2) ## repeat the array
pTheta = pTheta/pTheta.sum()
Data = np.append(np.zeros(13),np.ones(14))
BernGrid(Theta,pTheta,Data)
# Out:
#   <div class="bk-root" id="ab0deff7-22d8-4c41-b776-9ed8aedc82e3"></div>
